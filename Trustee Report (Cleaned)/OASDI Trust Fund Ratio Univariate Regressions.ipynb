# %%
import os
import pandas as pd

base_path = r"C:\Users\anoth\Downloads\404GX_Social-Security-Data-main\Trustee Report (Cleaned)"
base_path
# Out:
# 'C:\\Users\\anoth\\Downloads\\404GX_Social-Security-Data-main\\Trustee Report (Cleaned)'

# %%
import pandas as pd
import glob
from functools import reduce

files = glob.glob(base_path + "/*.csv")

dfs = []

for f in files:
    try:
        temp = pd.read_csv(f, encoding="utf-8")
    except UnicodeDecodeError:
        temp = pd.read_csv(f, encoding="latin1")
    
    if "Year" in temp.columns:
        temp["Year"] = temp["Year"].astype(str).str.strip()
        dfs.append(temp)

len(dfs)
# Out:
# 10

# %%
# start with the first dataframe
merged = dfs[0].copy()

for temp in dfs[1:]:
    # find overlapping columns OTHER than Year
    overlap = [c for c in temp.columns if c in merged.columns and c != "Year"]
    
    # drop those overlapping columns from the new df before merge
    if overlap:
        temp = temp.drop(columns=overlap)
    
    # now safe to merge
    merged = merged.merge(temp, on="Year", how="outer")

df = merged
df.columns
# Out:
# Index(['Assumption', 'Year', 'Average Annual Unemployment Rate',
#        'Labor Force Percentage Change', 'Total Employment Percentage Change',
#        'GDP Percentage Change', 'Average Annual Nominal Interest Rate',
#        'Average Annual Real Interest Rate', 'Covered workers',
#        'OASI Beneficiaries', 'DI Beneficiaries', 'OASDI Beneficiaries',
#        'Covered workers per OASDI beneficiary',
#        'OASDI beneficiaries per 100 covered workers', 'Total Fertility Rate',
#        'Age-sex-adjusted death rate per 100,000',
#        'Age-sex-adjusted death rate per 100,000 (Under 65)',
#        'Age-sex-adjusted death rate per 100,000 (65 and over)',
#        'LPR Immigration', 'LPR Emigration', 'Net LPR Change',
#        'Net Temporary or Unlawful Immigration Change', 'Income rate (OASDI)',
#        'Cost rate (OASDI)', 'Balance (OASDI)', 'Income rate (HI)',
#        'Cost rate (HI)', 'Balance (HI)',
#        'Worker (Retired workers & auxiliaries)',
#        'Spouse (Retired workers & auxiliaries)',
#        'Child (Retired workers & auxiliaries)', 'Widow-widower (Survivors)',
#        'Mother-father (Survivors)', 'Child (Survivors)', 'Parent (Survivors)',
#        'Total', 'Non-interest income (K)', 'Interest income (K)',
#        'Total income (K)', 'Cost (K)', 'Reserves at end of year (K)', 'Gender',
#        'Life Expectancy at Birth', 'Life Expectancy at Age 65',
#        'Ratio of OASDI Taxable Payroll to GDP', 'OASI Fund Ratio',
#        'DI Fund Ratio', 'OASDI Fund Ratio'],
#       dtype='object')

# %%
# convert year + filter
df["Year"] = pd.to_numeric(df["Year"], errors="coerce")
df = df[df["Year"] <= 2024].copy()

# collapse to unique years
df = df.groupby("Year", as_index=False).mean(numeric_only=True)


# create covid dummy
df["Covid_dummy"] = (df["Year"] == 2020).astype(int)

# %%
df["LE65_x_Covid"] = df["Life Expectancy at Age 65"] * df["Covid_dummy"]

# %%
import statsmodels.api as sm

# %%
# outcome (dependent) variables
outcome_cols = [
    "Reserves at end of year (K)",
    "Cost (K)",
    "OASDI Fund Ratio"
]

# columns to exclude from predictors
exclude_cols = set(outcome_cols + ["Year", "Assumption"])

# everything else will be a potential X
predictor_cols = [c for c in df.columns if c not in exclude_cols]

len(predictor_cols), predictor_cols[:10]
# Out:
# (43,
#  ['Average Annual Unemployment Rate',
#   'Labor Force Percentage Change',
#   'Total Employment Percentage Change',
#   'GDP Percentage Change',
#   'Average Annual Nominal Interest Rate',
#   'Average Annual Real Interest Rate',
#   'Covered workers',
#   'OASI Beneficiaries',
#   'OASDI Beneficiaries',
#   'Covered workers per OASDI beneficiary'])

# %%
results = []

for y_col in outcome_cols:
    for x_col in predictor_cols:
        # take just these two columns
        sub = df[[y_col, x_col]].copy()

        # force both columns to numeric, invalid values → NaN
        sub = sub.apply(pd.to_numeric, errors="coerce").dropna()

        # skip if too few data points or not enough variation in X
        if len(sub) < 10 or sub[x_col].nunique() < 3:
            continue

        X = sm.add_constant(sub[x_col])
        y = sub[y_col]

        model = sm.OLS(y, X).fit()

        results.append({
            "outcome": y_col,
            "predictor": x_col,
            "beta": model.params[x_col],
            "p_value": model.pvalues[x_col],
            "r_squared": model.rsquared,
            "n_obs": len(sub)
        })

results_df = pd.DataFrame(results)
results_df.head()
# Out:
#                        outcome                             predictor  \
# 0  Reserves at end of year (K)      Average Annual Unemployment Rate
# 1  Reserves at end of year (K)         Labor Force Percentage Change
# 2  Reserves at end of year (K)    Total Employment Percentage Change
# 3  Reserves at end of year (K)                 GDP Percentage Change
# 4  Reserves at end of year (K)  Average Annual Nominal Interest Rate
#
#            beta       p_value  r_squared  n_obs
# 0 -1.921634e+08  1.303456e-01   0.042649     55
# 1 -1.115981e+09  8.016235e-09   0.469211     55
# 2 -2.658844e+08  2.284262e-02   0.093952     55
# 3 -1.798782e+08  7.566559e-02   0.058331     55
# 4 -4.378756e+08  7.698956e-20   0.794300     55

# %%
results_df_sorted = results_df.sort_values(["outcome", "p_value"])
results_df_sorted
# Out:
#                         outcome                                     predictor  \
# 49                     Cost (K)                           OASDI Beneficiaries
# 48                     Cost (K)                            OASI Beneficiaries
# 66                     Cost (K)        Worker (Retired workers & auxiliaries)
# 73                     Cost (K)                                         Total
# 74                     Cost (K)                       Non-interest income (K)
# ..                          ...                                           ...
# 3   Reserves at end of year (K)                         GDP Percentage Change
# 21  Reserves at end of year (K)                               Balance (OASDI)
# 0   Reserves at end of year (K)              Average Annual Unemployment Rate
# 18  Reserves at end of year (K)  Net Temporary or Unlawful Immigration Change
# 11  Reserves at end of year (K)                          Total Fertility Rate
#
#             beta       p_value  r_squared  n_obs
# 49  2.862999e+04  1.917422e-62   0.994903     55
# 48  3.573644e+04  7.070810e-51   0.986077     55
# 66  3.320222e+04  5.714296e-50   0.990288     50
# 73  3.638035e+04  1.491671e-45   0.985164     50
# 74  1.054629e+00  3.054957e-33   0.935612     55
# ..           ...           ...        ...    ...
# 3  -1.798782e+08  7.566559e-02   0.058331     55
# 21 -2.778981e+08  1.200241e-01   0.044991     55
# 0  -1.921634e+08  1.303456e-01   0.042649     55
# 18  5.793770e+05  1.707399e-01   0.035108     55
# 11 -1.135344e+09  3.775554e-01   0.014721     55
#
# [123 rows x 6 columns]

# %%
focus_names = [
    "Total Fertility Rate",
    "Life Expectancy at Birth",
    "Life Expectancy at Birth, Male",
    "Life Expectancy at Birth, Female",
    "Net LPR Change"
]

focus_cols = [c for c in focus_names if c in predictor_cols]

focus_cols
# Out:
# ['Total Fertility Rate', 'Life Expectancy at Birth', 'Net LPR Change']

# %%
focus_results = results_df_sorted[results_df_sorted["predictor"].isin(focus_cols)]
focus_results
# Out:
#                          outcome                 predictor          beta  \
# 77                      Cost (K)  Life Expectancy at Birth  1.324313e+08
# 58                      Cost (K)            Net LPR Change  6.739309e+05
# 52                      Cost (K)      Total Fertility Rate -8.793399e+08
# 118             OASDI Fund Ratio  Life Expectancy at Birth  6.052626e-01
# 99              OASDI Fund Ratio            Net LPR Change  2.089047e-03
# 93              OASDI Fund Ratio      Total Fertility Rate  1.583087e+00
# 36   Reserves at end of year (K)  Life Expectancy at Birth  5.891452e+08
# 17   Reserves at end of year (K)            Net LPR Change  2.855016e+06
# 11   Reserves at end of year (K)      Total Fertility Rate -1.135344e+09
#
#           p_value  r_squared  n_obs
# 77   6.396261e-20   0.795728     55
# 58   2.659636e-05   0.285395     55
# 52   1.285260e-03   0.179106     55
# 118  8.478410e-19   0.807527     50
# 99   1.911098e-03   0.183520     50
# 93   2.056005e-01   0.033164     50
# 36   7.058229e-19   0.776454     55
# 17   9.243779e-05   0.252534     55
# 11   3.775554e-01   0.014721     55

# %%
# Special COVID model:
sub = df[["OASDI Fund Ratio", "Life Expectancy at Age 65", "Covid_dummy"]].copy()
sub = sub.apply(pd.to_numeric, errors="coerce").dropna()

X = sm.add_constant(sub[["Life Expectancy at Age 65", "Covid_dummy"]])
y = sub["OASDI Fund Ratio"]

covid_model = sm.OLS(y, X).fit()
print(covid_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       OASDI Fund Ratio   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     71.93
# Date:                Sun, 07 Dec 2025   Prob (F-statistic):           4.98e-15
# Time:                        18:46:18   Log-Likelihood:                -46.020
# No. Observations:                  50   AIC:                             98.04
# Df Residuals:                      47   BIC:                             103.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -15.2664      1.434    -10.643      0.000     -18.152     -12.381
# Life Expectancy at Age 65     0.9663      0.081     11.926      0.000       0.803       1.129
# Covid_dummy                   0.2522      0.635      0.397      0.693      -1.024       1.529
# ==============================================================================
# Omnibus:                        1.835   Durbin-Watson:                   0.174
# Prob(Omnibus):                  0.400   Jarque-Bera (JB):                1.136
# Skew:                          -0.349   Prob(JB):                        0.567
# Kurtosis:                       3.242   Cond. No.                         288.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# ---- Interaction regression only for OASDI Fund Ratio ----
sub = df[[
    "OASDI Fund Ratio",
    "Life Expectancy at Age 65",
    "Covid_dummy",
    "LE65_x_Covid"
]].copy()

sub = sub.apply(pd.to_numeric, errors="coerce").dropna()

X = sm.add_constant(sub[[
    "Life Expectancy at Age 65",
    "Covid_dummy",
    "LE65_x_Covid"
]])
y = sub["OASDI Fund Ratio"]

interaction_model = sm.OLS(y, X).fit()
print(interaction_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       OASDI Fund Ratio   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     71.93
# Date:                Sun, 07 Dec 2025   Prob (F-statistic):           4.98e-15
# Time:                        18:46:18   Log-Likelihood:                -46.020
# No. Observations:                  50   AIC:                             98.04
# Df Residuals:                      47   BIC:                             103.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -15.2664      1.434    -10.643      0.000     -18.152     -12.381
# Life Expectancy at Age 65     0.9663      0.081     11.926      0.000       0.803       1.129
# Covid_dummy                   0.0008      0.002      0.397      0.693      -0.003       0.005
# LE65_x_Covid                  0.0138      0.035      0.397      0.693      -0.056       0.084
# ==============================================================================
# Omnibus:                        1.835   Durbin-Watson:                   0.174
# Prob(Omnibus):                  0.400   Jarque-Bera (JB):                1.136
# Skew:                          -0.349   Prob(JB):                        0.567
# Kurtosis:                       3.242   Cond. No.                     3.14e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.6e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
results_df_sorted.to_csv("all_univariate_results.csv", index=False)
focus_results.to_csv("focus_univariate_results.csv", index=False)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Year  Average Annual Unemployment Rate  Labor Force Percentage Change  \
# 0   1940.0                               NaN                            NaN
# 1   1941.0                               NaN                            NaN
# 2   1942.0                               NaN                            NaN
# 3   1943.0                               NaN                            NaN
# 4   1944.0                               NaN                            NaN
# ..     ...                               ...                            ...
# 80  2020.0                               8.1                           -1.7
# 81  2021.0                               5.4                            0.3
# 82  2022.0                               3.6                            1.9
# 83  2023.0                               3.6                            1.7
# 84  2024.0                               4.1                            0.7
#
#     Total Employment Percentage Change  GDP Percentage Change  \
# 0                                  NaN                    NaN
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
# ..                                 ...                    ...
# 80                                -6.2                   -2.2
# 81                                 3.2                    6.1
# 82                                 3.7                    2.5
# 83                                 1.7                    2.9
# 84                                 0.3                    2.8
#
#     Average Annual Nominal Interest Rate  Average Annual Real Interest Rate  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ..                                   ...                                ...
# 80                                   1.0                                1.0
# 81                                   1.4                               -4.1
# 82                                   3.0                               -6.5
# 83                                   4.1                               -0.8
# 84                                   4.3                                1.3
#
#     Covered workers  OASI Beneficiaries  OASDI Beneficiaries  ...  \
# 0               NaN                 NaN                  NaN  ...
# 1               NaN                 NaN                  NaN  ...
# 2               NaN                 NaN                  NaN  ...
# 3               NaN                 NaN                  NaN  ...
# 4               NaN                 NaN                  NaN  ...
# ..              ...                 ...                  ...  ...
# 80         175244.0             54843.0              64686.0  ...
# 81         176995.0             55546.0              65032.0  ...
# 82         181099.0             56544.0              65614.0  ...
# 83         182689.0             57924.0              66631.0  ...
# 84         183936.0             59556.0              67868.0  ...
#
#         Cost (K)  Reserves at end of year (K)  Life Expectancy at Birth  \
# 0            NaN                          NaN                     63.55
# 1            NaN                          NaN                     64.20
# 2            NaN                          NaN                     65.00
# 3            NaN                          NaN                     64.65
# 4            NaN                          NaN                     65.25
# ..           ...                          ...                       ...
# 80  1.382900e+09                 3.632400e+09                     77.00
# 81  1.358100e+09                 3.384200e+09                     76.40
# 82  1.360800e+09                 3.095900e+09                     77.45
# 83  1.466900e+09                 2.938200e+09                     78.45
# 84  1.521400e+09                 2.788600e+09                     79.05
#
#     Life Expectancy at Age 65  Ratio of OASDI Taxable Payroll to GDP  \
# 0                       12.65                                    NaN
# 1                       13.00                                    NaN
# 2                       13.25                                    NaN
# 3                       12.90                                    NaN
# 4                       13.30                                    NaN
# ..                        ...                                    ...
# 80                      18.25                                  0.361
# 81                      18.30                                  0.353
# 82                      18.80                                  0.351
# 83                      19.40                                  0.353
# 84                      19.60                                  0.347
#
#     OASI Fund Ratio  DI Fund Ratio  OASDI Fund Ratio  Covid_dummy  \
# 0               NaN            NaN               NaN            0
# 1               NaN            NaN               NaN            0
# 2               NaN            NaN               NaN            0
# 3               NaN            NaN               NaN            0
# 4               NaN            NaN               NaN            0
# ..              ...            ...               ...          ...
# 80             2.92           0.64              2.62            1
# 81             2.81           0.68              2.54            0
# 82             2.51           0.68              2.29            0
# 83             2.19           0.76              2.03            0
# 84             1.99           0.93              1.88            0
#
#     LE65_x_Covid
# 0           0.00
# 1           0.00
# 2           0.00
# 3           0.00
# 4           0.00
# ..           ...
# 80         18.25
# 81          0.00
# 82          0.00
# 83          0.00
# 84          0.00
#
# [85 rows x 47 columns]>

# %%
df.to_csv("final_clean_dataset.csv", index=False)
